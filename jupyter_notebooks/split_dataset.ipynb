# %% [markdown]
# This notebook demonstrate how to split the datasets into training, validation, and testing sets

# %%
# pip install -U scikit-learn

# %% [markdown]
# ## Clone the repository

# %%
# !git clone https://github.com/gyasifred/kasafranse.git
# Out:
# Cloning into 'kasafranse'...
# remote: Enumerating objects: 250, done.
# remote: Counting objects: 100% (250/250), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 250 (delta 169), reused 173 (delta 97), pack-reused 0
# Receiving objects: 100% (250/250), 71.99 KiB | 455.00 KiB/s, done.
# Resolving deltas: 100% (169/169), done.

# %%
# %cd kasafranse/
# Out:
# /home/kgyasi/Desktop/kasafranse/jupyter_notebooks/kasafranse

# %%
# !ls
# Out:
# get_bleu.py		      __init__.py	  train_test_split.py
# get_sacrebleu.py	      kasafranse	  train_translator.py
# googleapibleu.py	      pivot_translate.py  translate.py
# googleAPIdirect_translate.py  preprocess_data.py  translator_bleu.py
# googleAPIpivot_translate.py   README.md		  translator_sacrebleu.py
# googleapisacrebleu.py	      requirements.txt

# %% [markdown]
# ### get train, validation, and test sets

# %%
# !python train_test_split.py -h
# Out:
# usage: train_test_split.py [-h] [--val_set VAL_SET] [--output_dir OUTPUT_DIR]
#                            filepath_1 filepath_2 filepath_3
#
# Split dataset into Training, validation and Testing sets
#
# positional arguments:
#   filepath_1            Enter the file path of Twi document
#   filepath_2            Enter the file path of English document
#   filepath_3            Enter the file path of French document
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --val_set VAL_SET     Pass True if validation set is required. Default =
#                         False
#   --output_dir OUTPUT_DIR
#                         Pass output directory

# %%
# !python train_test_split.py \
../../dataset/verified_twi \
../../dataset/verified_english \
../../dataset/verified_french \
--val True \
--output_dir ../../dataset
