# %% [markdown]
# <a href="https://colab.research.google.com/github/gyasifred/kasafranse/blob/main/seq2seq_nmt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q -U tensorflow-text tensorflow
# Out:
#      |████████████████████████████████| 5.9 MB 14.8 MB/s
#      |████████████████████████████████| 578.0 MB 15 kB/s
#      |████████████████████████████████| 5.9 MB 46.5 MB/s
#      |████████████████████████████████| 438 kB 67.7 MB/s
#      |████████████████████████████████| 1.7 MB 54.2 MB/s

# %% [markdown]
# # clone repository

# %%
# !git clone https://github.com/gyasifred/kasafranse.git
# Out:
# Cloning into 'kasafranse'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 43 (delta 11), reused 38 (delta 10), pack-reused 0
# Unpacking objects: 100% (43/43), done.

# %%
! ls
# Out:
# drive  kasafranse  sample_data

# %%
# %cd kasafranse
# Out:
# /content/kasafranse

# %%
# !ls
# Out:
# build_sub_word_tokenizer.py	      requirements.txt
# fine_turned_bleu.py		      seq2seq_bleu.py
# fine_turned_transformer.py	      seq2seq_translate.py
# fine_turned_transformer_translate.py  text_vectorization.py
# googleAPIdirect_translate.py	      train_seq2seq_nmt.py
# googleAPIpivot_translate.py	      train_test_split.py
# __init__.py			      train_transformer.py
# kasafranse			      transformer_bleu.py
# README.md			      transformer_translate.py

# %% [markdown]
# # process training and tests sets

# %%
# get help message
# !python train_test_split.py -h
# Out:
# usage: train_test_split.py [-h] [--val_set VAL_SET] [--output_dir OUTPUT_DIR]
#                            filepath_1 filepath_2 filepath_3
#
# Split dataset into Training, validation and Testing sets
#
# positional arguments:
#   filepath_1            Enter the file path of Twi document
#   filepath_2            Enter the file path of English document
#   filepath_3            Enter the file path of French document
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --val_set VAL_SET     Pass True if validation set is required. Default =
#                         False
#   --output_dir OUTPUT_DIR
#                         Pass output directory

# %%
# !python train_test_split.py /content/drive/MyDrive/data/verified.twi.txt\
/content/drive/MyDrive/data/verified_english.txt\
/content/drive/MyDrive/data/verified.french.txt\
--output_dir /content/drive/MyDrive/data

# %% [markdown]
# # Build tokenizer

# %%
# !python text_vectorization.py -h
# Out:
# 2022-10-03 14:01:11.659004: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-03 14:01:11.834209: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-03 14:01:12.619088: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# !python text_vectorization.py /content/drive/MyDrive/data/train_twi.txt\
/content/drive/MyDrive/data/train_fr.txt\
/content/drive/MyDrive/data/train_en.txt\
5000\
--save_dir /content/drive/MyDrive/models
# Out:
# 2022-10-03 14:04:47.433886: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-03 14:04:47.602283: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-03 14:04:48.362485: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %% [markdown]
# # train seq2seq model

# %%
# get help message
# !python train_seq2seq_nmt.py -h
# Out:
# 2022-10-03 14:06:48.036122: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-03 14:06:48.208392: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-03 14:06:48.950925: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# !python train_seq2seq_nmt.py /content/drive/MyDrive/data/train_en.txt\
/content/drive/MyDrive/data/train_twi.txt\
/content/drive/MyDrive/models/english_tokenizer.pkl\
/content/drive/MyDrive/models/twi_tokenizer.pkl\
seq2seq-en-tw-translator\
--batch_size 50\
--epoch 50\
--save_dir /content/drive/MyDrive/models
# Out:
# 2022-10-03 14:27:50.689303: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-03 14:27:50.854729: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-03 14:27:51.608029: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...
