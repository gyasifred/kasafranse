# %% [markdown]
# <a href="https://colab.research.google.com/github/gyasifred/kasafranse/blob/main/train_transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install required packages

# %%
! pip uninstall -y -q tensorflow keras tensorflow-estimator tensorflow-text
! pip install -q -U tensorflow-text tensorflow
# Out:
# WARNING: Skipping tensorflow-text as it is not installed.
#      |████████████████████████████████| 5.9 MB 23.6 MB/s
#      |████████████████████████████████| 578.0 MB 15 kB/s
#      |████████████████████████████████| 438 kB 62.9 MB/s
#      |████████████████████████████████| 1.7 MB 68.9 MB/s
#      |████████████████████████████████| 5.9 MB 63.3 MB/s

# %% [markdown]
# ## Clone repository

# %%
! git clone https://github.com/gyasifred/kasafranse.git
# Out:
# Cloning into 'kasafranse'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 32 (delta 6), reused 32 (delta 6), pack-reused 0
# Unpacking objects: 100% (32/32), done.

# %%
# %cd kasafranse/
# Out:
# /content/kasafranse

# %%
# !ls
# Out:
# build_sub_word_tokenizer.py	      seq2seq_bleu.py
# fine_turned_bleu.py		      seq2seq_translate.py
# fine_turned_transformer.py	      text_vectorization.py
# fine_turned_transformer_translate.py  train_seq2seq_nmt.py
# googleAPIdirect_translate.py	      train_test_split.py
# googleAPIpivot_translate.py	      train_transformer.py
# __init__.py			      transformer_bleu.py
# kasafranse			      transformer_translate.py
# README.md

# %% [markdown]
# ## Process training and test sets

# %%
# get help message 
! python train_test_split.py -h
# Out:
# usage: train_test_split.py [-h] [--val_set VAL_SET] [--output_dir OUTPUT_DIR]
#                            filepath_1 filepath_2 filepath_3
#
# Split dataset into Training, validation and Testing sets
#
# positional arguments:
#   filepath_1            Enter the file path of Twi document
#   filepath_2            Enter the file path of English document
#   filepath_3            Enter the file path of English document
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --val_set VAL_SET     Pass True if validation set is required. Default =
#                         False
#   --output_dir OUTPUT_DIR
#                         Pass output directory

# %%
! python train_test_split.py /content/drive/MyDrive/verified_twi.txt /content/drive/MyDrive/verified_english.txt\
 /content/drive/MyDrive/verified_english_french.txt --output_dir /content/drive/MyDrive/data

# %% [markdown]
# ## Build Tokenizer

# %%
# get help for tokenizer
! python build_sub_word_tokenizer.py -h
# Out:
# 2022-10-02 16:26:43.126444: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-02 16:26:43.303685: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-02 16:26:44.077384: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
! python build_sub_word_tokenizer.py /content/drive/MyDrive/data/train_twi.txt /content/drive/MyDrive/data/train_fr.txt \
/content/drive/MyDrive/data/train_en.txt 5000 --tokenizer_name translate_entwifr_converter --save_dir /content/drive/MyDrive/models
# Out:
# 2022-10-02 16:26:46.359857: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-02 16:26:46.535082: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-02 16:26:47.450512: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %% [markdown]
# ## train english twi transformer

# %%
# get help meassage
! python train_transformer.py -h
# Out:
# 2022-10-02 16:28:14.369077: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-02 16:28:14.544756: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-02 16:28:15.318339: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
! python train_transformer.py /content/drive/MyDrive/data/train_en.txt /content/drive/MyDrive/data/train_twi.txt \
/content/drive/MyDrive/models/translate_entwifr_converter english_twi_transltor --buffer_size 30000 --max_input_length 50\
--batch_size 64  --num_layers 6  --d_model 512 --dff 2048 --heads 8 --epoch 150 --save_dir /content/drive/MyDrive/models
# Out:
# python3: can't open file 'train_transformer.py': [Errno 2] No such file or directory
